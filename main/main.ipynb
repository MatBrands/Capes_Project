# %%
import pandas as pd
import numpy as np
from nltk import FreqDist
from nltk.tokenize import wordpunct_tokenize

# %%
df = pd.read_pickle('./Processed/2016.pkl')

# %%
df.head()
# Out:
#                                               resumo area_avaliacao
# 0  promulgar correspondente solicitação hoje reco...  engenharias i
# 1  ramo empregar ponto estaiar necessário longo c...  engenharias i
# 2  hcnel achar seguimento metade aéreo caso persi...    medicina ii
# 3  anterior esquerr fa relacionar apresentar dive...    medicina ii
# 4  jaqueta real demonstrar ambiental físicar estr...  engenharias i

# %%
def freq_dist(array: list) -> dict:
    text = ' '.join(array)
    return FreqDist(wordpunct_tokenize(text))

# %%
frequencia = freq_dist(df.resumo)

frequencia.most_common(5)
# Out:
# [('de', 864),
#  ('este', 706),
#  ('estudo', 613),
#  ('trabalho', 555),
#  ('objetivo', 530)]

# %%
freq = dict(frequencia)

for character in freq:
    aux = freq[character]
    freq[character] = {}
    freq[character]['frequencia'] = aux
    for item in df.area_avaliacao.unique():
        freq[character][item] = 0
        
    areas = df[df.resumo.str.contains(character)].area_avaliacao
    for item in areas:
        freq[character][item] += 1
        
freq = pd.DataFrame(freq).transpose()

# %%
freq.sort_values(by='frequencia', ascending=False)
# Out:
#               frequencia  engenharias i  medicina ii  interdisciplinar  \
# de                   864             27           48                78
# este                 706             20           28                45
# estudo               613             15           39                52
# trabalho             555             16           17                39
# objetivo             530             12           35                54
# ...                  ...            ...          ...               ...
# tics                   1              0            2                 0
# guiam                  1              0            0                 0
# factual                1              0            0                 0
# demonstre              1              0            0                 0
# singularizar           1              0            0                 1
#
#               ciências biológicas i  letras / linguística  biodiversidade  \
# de                               47                    76              38
# este                             35                    36              26
# estudo                           29                    53              25
# trabalho                         28                    35              13
# objetivo                         19                    26              13
# ...                             ...                   ...             ...
# tics                              0                     0               0
# guiam                             0                     0               0
# factual                           0                     0               0
# demonstre                         0                     0               0
# singularizar                      0                     0               0
#
#               ciência da computação  ciências agrárias i  \
# de                               26                  103
# este                             16                   76
# estudo                           13                   44
# trabalho                         16                   74
# objetivo                         14                   74
# ...                             ...                  ...
# tics                              0                    0
# guiam                             0                    0
# factual                           0                    0
# demonstre                         0                    0
# singularizar                      0                    0
#
#               antropologia / arqueologia  ...  astronomia / física  \
# de                                     1  ...                   37
# este                                   0  ...                   34
# estudo                                 1  ...                   17
# trabalho                               0  ...                   22
# objetivo                               0  ...                    9
# ...                                  ...  ...                  ...
# tics                                   0  ...                    0
# guiam                                  0  ...                    0
# factual                                0  ...                    0
# demonstre                              0  ...                    0
# singularizar                           0  ...                    0
#
#               administração, ciências contábeis e turismo  saúde coletiva  \
# de                                                     11              24
# este                                                    7              14
# estudo                                                 10              22
# trabalho                                                7               8
# objetivo                                                7              21
# ...                                                   ...             ...
# tics                                                    0               0
# guiam                                                   0               0
# factual                                                 0               0
# demonstre                                               0               0
# singularizar                                            0               0
#
#               química  farmácia  filosofia/teologia:subcomissão filosofia  \
# de                 19        29                                         2
# este               17        26                                         0
# estudo             12        17                                         0
# trabalho           17        16                                         0
# objetivo            5        15                                         0
# ...               ...       ...                                       ...
# tics                0         0                                         0
# guiam               0         0                                         0
# factual             0         0                                         0
# demonstre           0         0                                         0
# singularizar        0         0                                         0
#
#               ciência política e relações internacionais  sociologia  direito  \
# de                                                     6          17        3
# este                                                   4           6        2
# estudo                                                 3          10        2
# trabalho                                               4           9        1
# objetivo                                               1           6        1
# ...                                                  ...         ...      ...
# tics                                                   0           0        0
# guiam                                                  0           0        0
# factual                                                0           0        0
# demonstre                                              0           0        0
# singularizar                                           0           0        0
#
#               filosofia/teologia:subcomissão teologia
# de                                                  3
# este                                                3
# estudo                                              1
# trabalho                                            1
# objetivo                                            2
# ...                                               ...
# tics                                                0
# guiam                                               0
# factual                                             0
# demonstre                                           0
# singularizar                                        0
#
# [20355 rows x 35 columns]
